# %% [markdown]
# <a href="https://colab.research.google.com/github/Karandeep07/Weapon-Detection/blob/main/Handgun_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# For Dataset trying local path instead of uploading

# %%
# !pip install -q --use-deprecated=legacy-resolver tflite-model-maker
# !pip install -q pycocotools
# Out:
#      |████████████████████████████████| 616 kB 27.5 MB/s
#      |████████████████████████████████| 234 kB 56.0 MB/s
#      |████████████████████████████████| 596 kB 58.9 MB/s
#      |████████████████████████████████| 6.4 MB 56.1 MB/s
#      |████████████████████████████████| 120 kB 68.5 MB/s
#      |████████████████████████████████| 1.1 MB 59.7 MB/s
#      |████████████████████████████████| 1.2 MB 54.1 MB/s
#      |████████████████████████████████| 3.4 MB 57.7 MB/s
#      |████████████████████████████████| 87 kB 7.7 MB/s
#      |████████████████████████████████| 77 kB 6.5 MB/s
#      |████████████████████████████████| 1.1 MB 56.1 MB/s
#      |████████████████████████████████| 840 kB 72.6 MB/s
#      |████████████████████████████████| 462 kB 59.2 MB/s
#      |████████████████████████████████| 25.3 MB 1.2 MB/s
#      |████████████████████████████████| 211 kB 65.7 MB/s
#      |████████████████████████████████| 352 kB 61.6 MB/s
#      |████████████████████████████████| 47.7 MB 76 kB/s
#      |████████████████████████████████| 99 kB 10.7 MB/s
#   Building wheel for fire (setup.py) ... done
#   Building wheel for py-cpuinfo (setup.py) ... done

# %% [markdown]
# Import the required packages.

# %%
import numpy as np
import os

from tflite_model_maker.config import QuantizationConfig
from tflite_model_maker.config import ExportFormat
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)

# %% [markdown]
# Load Dataset from local pc

# %% [markdown]
# Uploading zip & extract

# %%
from zipfile import ZipFile
file_name = '/content/train.zip'

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
file_name = '/content/val.zip'

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
tr_image_dir= '/content/train'
val_image_dir='/content/val'

# %% [markdown]
# Creating label map

# %%
label_map={1:'pistol'}
print(label_map)
# Out:
# {1: 'pistol'}

# %% [markdown]
# Load data. Data is loaded as tfrecord and stored in the cache_dir location, for fast future use.

# %%
train_ds = object_detector.DataLoader.from_pascal_voc(images_dir=tr_image_dir,
                                                      annotations_dir= tr_image_dir,
                                                      label_map=label_map,
                                                      cache_dir='/content/cache/train')

# %%
val_ds = object_detector.DataLoader.from_pascal_voc(images_dir=val_image_dir,
                                                      annotations_dir= val_image_dir,
                                                      label_map=label_map,
                                                      cache_dir='/content/cache/train'
                                                     )

# %%
print("Train dataset contains {} images".format(train_ds.__len__()))
print("Validation dataset contains {} images".format(val_ds.__len__()))
# Out:
# Train dataset contains 2371 images
# Validation dataset contains 600 images

# %%
spec = model_spec.get('efficientdet_lite2')

# %%
model = object_detector.ObjectDetector.create(train_data=train_ds, #train dataset
                                             model_spec=spec, #model specification
                                             #epochs=100, #training epochs
                                             validation_data = val_ds, #validation subset
                                             batch_size= 8, 
                                             train_whole_model=True, #Train whole model or just layers that are not freezed. 
                                             )
# Out:
# Epoch 1/50
# 296/296 [==============================] - 195s 491ms/step - det_loss: 0.8371 - cls_loss: 0.5146 - box_loss: 0.0064 - reg_l2_loss: 0.0764 - loss: 0.9134 - learning_rate: 0.0090 - gradient_norm: 4.8352 - val_det_loss: 0.3939 - val_cls_loss: 0.2415 - val_box_loss: 0.0030 - val_reg_l2_loss: 0.0770 - val_loss: 0.4709
# Epoch 2/50
# 296/296 [==============================] - 145s 491ms/step - det_loss: 0.5673 - cls_loss: 0.3490 - box_loss: 0.0044 - reg_l2_loss: 0.0775 - loss: 0.6447 - learning_rate: 0.0100 - gradient_norm: 4.1033 - val_det_loss: 0.2695 - val_cls_loss: 0.1909 - val_box_loss: 0.0016 - val_reg_l2_loss: 0.0779 - val_loss: 0.3473
# Epoch 3/50
# 296/296 [==============================] - 146s 492ms/step - det_loss: 0.5133 - cls_loss: 0.3147 - box_loss: 0.0040 - reg_l2_loss: 0.0782 - loss: 0.5915 - learning_rate: 0.0099 - gradient_norm: 3.7634 - val_det_loss: 0.2160 - val_cls_loss: 0.1574 - val_box_loss: 0.0012 - val_reg_l2_loss: 0.0786 - val_loss: 0.2946
# Epoch 4/50
# 296/296 [==============================] - 146s 495ms/step - det_loss: 0.4794 - cls_loss: 0.2993 - box_loss: 0.0036 - reg_l2_loss: 0.0789 - loss: 0.5583 - learning_rate: 0.0099 - gradient_norm: 3.5816 - val_det_loss: 0.2029 - val_cls_loss: 0.1405 - val_box_loss: 0.0012 - val_reg_l2_loss: 0.0792 - val_loss: 0.2821
# Epoch 5/50
# 296/296 [==============================] - 168s 569ms/step - det_loss: 0.4608 - cls_loss: 0.2866 - box_loss: 0.0035 - reg_l2_loss: 0.0794 - loss: 0.5402 - learning_rate: 0.0098 - gradient_norm: 3.5244 - val_det_loss: 0.2452 - val_cls_loss: 0.1567 - val_box_loss: 0.0018 - val_reg_l2_loss: 0.0797 - val_loss: 0.3250
# Epoch 6/50
# 296/296 [==============================] - 146s 491ms/step - det_loss: 0.4313 - cls_loss: 0.2698 - box_loss: 0.0032 - reg_l2_loss: 0.0800 - loss: 0.5113 - learning_rate: 0.0097 - gradient_norm: 3.3466 - val_det_loss: 0.1977 - val_cls_loss: 0.1377 - val_box_loss: 0.0012 - val_reg_l2_loss: 0.0802 - val_loss: 0.2779
# Epoch 7/50
# 296/296 [==============================] - 147s 497ms/step - det_loss: 0.4334 - cls_loss: 0.2727 - box_loss: 0.0032 - reg_l2_loss: 0.0805 - loss: 0.5138 - learning_rate: 0.0096 - gradient_norm: 3.2767 - val_det_loss: 0.1694 - val_cls_loss: 0.1142 - val_box_loss: 0.0011 - val_reg_l2_loss: 0.0807 - val_loss: 0.2501
# Epoch 8/50
# 296/296 [==============================] - 146s 494ms/step - det_loss: 0.4165 - cls_loss: 0.2617 - box_loss: 0.0031 - reg_l2_loss: 0.0809 - loss: 0.4974 - learning_rate: 0.0094 - gradient_norm: 3.1840 - val_det_loss: 0.1723 - val_cls_loss: 0.1074 - val_box_loss: 0.0013 - val_reg_l2_loss: 0.0810 - val_loss: 0.2533
# Epoch 9/50
# 296/296 [==============================] - 146s 494ms/step - det_loss: 0.4072 - cls_loss: 0.2562 - box_loss: 0.0030 - reg_l2_loss: 0.0812 - loss: 0.4884 - learning_rate: 0.0093 - gradient_norm: 3.2328 - val_det_loss: 0.1830 - val_cls_loss: 0.1302 - val_box_loss: 0.0011 - val_reg_l2_loss: 0.0814 - val_loss: 0.2645
# Epoch 10/50
# 296/296 [==============================] - 164s 554ms/step - det_loss: 0.4006 - cls_loss: 0.2525 - box_loss: 0.0030 - reg_l2_loss: 0.0816 - loss: 0.4823 - learning_rate: 0.0091 - gradient_norm: 3.1734 - val_det_loss: 0.1449 - val_cls_loss: 0.1051 - val_box_loss: 7.9525e-04 - val_reg_l2_loss: 0.0818 - val_loss: 0.2267
# Epoch 11/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.3810 - cls_loss: 0.2433 - box_loss: 0.0028 - reg_l2_loss: 0.0820 - loss: 0.4630 - learning_rate: 0.0089 - gradient_norm: 3.2658 - val_det_loss: 0.1628 - val_cls_loss: 0.1120 - val_box_loss: 0.0010 - val_reg_l2_loss: 0.0822 - val_loss: 0.2449
# Epoch 12/50
# 296/296 [==============================] - 147s 496ms/step - det_loss: 0.3751 - cls_loss: 0.2346 - box_loss: 0.0028 - reg_l2_loss: 0.0823 - loss: 0.4574 - learning_rate: 0.0087 - gradient_norm: 3.1781 - val_det_loss: 0.1550 - val_cls_loss: 0.1118 - val_box_loss: 8.6401e-04 - val_reg_l2_loss: 0.0825 - val_loss: 0.2375
# Epoch 13/50
# 296/296 [==============================] - 147s 496ms/step - det_loss: 0.3687 - cls_loss: 0.2349 - box_loss: 0.0027 - reg_l2_loss: 0.0826 - loss: 0.4513 - learning_rate: 0.0085 - gradient_norm: 3.0940 - val_det_loss: 0.1606 - val_cls_loss: 0.1027 - val_box_loss: 0.0012 - val_reg_l2_loss: 0.0828 - val_loss: 0.2434
# Epoch 14/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.3639 - cls_loss: 0.2307 - box_loss: 0.0027 - reg_l2_loss: 0.0829 - loss: 0.4469 - learning_rate: 0.0082 - gradient_norm: 3.1501 - val_det_loss: 0.1913 - val_cls_loss: 0.1286 - val_box_loss: 0.0013 - val_reg_l2_loss: 0.0831 - val_loss: 0.2744
# Epoch 15/50
# 296/296 [==============================] - 163s 552ms/step - det_loss: 0.3581 - cls_loss: 0.2277 - box_loss: 0.0026 - reg_l2_loss: 0.0832 - loss: 0.4413 - learning_rate: 0.0080 - gradient_norm: 3.1548 - val_det_loss: 0.1605 - val_cls_loss: 0.1115 - val_box_loss: 9.8106e-04 - val_reg_l2_loss: 0.0833 - val_loss: 0.2439
# Epoch 16/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.3388 - cls_loss: 0.2154 - box_loss: 0.0025 - reg_l2_loss: 0.0834 - loss: 0.4223 - learning_rate: 0.0077 - gradient_norm: 3.0376 - val_det_loss: 0.1035 - val_cls_loss: 0.0805 - val_box_loss: 4.5875e-04 - val_reg_l2_loss: 0.0835 - val_loss: 0.1870
# Epoch 17/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.3386 - cls_loss: 0.2151 - box_loss: 0.0025 - reg_l2_loss: 0.0837 - loss: 0.4222 - learning_rate: 0.0075 - gradient_norm: 3.1592 - val_det_loss: 0.1137 - val_cls_loss: 0.0809 - val_box_loss: 6.5570e-04 - val_reg_l2_loss: 0.0838 - val_loss: 0.1975
# Epoch 18/50
# 296/296 [==============================] - 147s 497ms/step - det_loss: 0.3340 - cls_loss: 0.2132 - box_loss: 0.0024 - reg_l2_loss: 0.0839 - loss: 0.4179 - learning_rate: 0.0072 - gradient_norm: 3.1105 - val_det_loss: 0.1182 - val_cls_loss: 0.0973 - val_box_loss: 4.1856e-04 - val_reg_l2_loss: 0.0840 - val_loss: 0.2021
# Epoch 19/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.3192 - cls_loss: 0.2044 - box_loss: 0.0023 - reg_l2_loss: 0.0840 - loss: 0.4032 - learning_rate: 0.0069 - gradient_norm: 3.0157 - val_det_loss: 0.1051 - val_cls_loss: 0.0834 - val_box_loss: 4.3241e-04 - val_reg_l2_loss: 0.0841 - val_loss: 0.1892
# Epoch 20/50
# 296/296 [==============================] - 162s 548ms/step - det_loss: 0.3089 - cls_loss: 0.1975 - box_loss: 0.0022 - reg_l2_loss: 0.0842 - loss: 0.3931 - learning_rate: 0.0066 - gradient_norm: 2.8979 - val_det_loss: 0.1217 - val_cls_loss: 0.0925 - val_box_loss: 5.8519e-04 - val_reg_l2_loss: 0.0842 - val_loss: 0.2059
# Epoch 21/50
# 296/296 [==============================] - 146s 492ms/step - det_loss: 0.3017 - cls_loss: 0.1936 - box_loss: 0.0022 - reg_l2_loss: 0.0843 - loss: 0.3860 - learning_rate: 0.0063 - gradient_norm: 3.0538 - val_det_loss: 0.1696 - val_cls_loss: 0.1281 - val_box_loss: 8.3040e-04 - val_reg_l2_loss: 0.0844 - val_loss: 0.2539
# Epoch 22/50
# 296/296 [==============================] - 147s 496ms/step - det_loss: 0.2995 - cls_loss: 0.1924 - box_loss: 0.0021 - reg_l2_loss: 0.0844 - loss: 0.3839 - learning_rate: 0.0060 - gradient_norm: 3.0181 - val_det_loss: 0.1082 - val_cls_loss: 0.0771 - val_box_loss: 6.2180e-04 - val_reg_l2_loss: 0.0845 - val_loss: 0.1926
# Epoch 23/50
# 296/296 [==============================] - 146s 495ms/step - det_loss: 0.2868 - cls_loss: 0.1827 - box_loss: 0.0021 - reg_l2_loss: 0.0845 - loss: 0.3713 - learning_rate: 0.0056 - gradient_norm: 2.9431 - val_det_loss: 0.0929 - val_cls_loss: 0.0763 - val_box_loss: 3.3212e-04 - val_reg_l2_loss: 0.0845 - val_loss: 0.1775
# Epoch 24/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2832 - cls_loss: 0.1828 - box_loss: 0.0020 - reg_l2_loss: 0.0846 - loss: 0.3678 - learning_rate: 0.0053 - gradient_norm: 2.8522 - val_det_loss: 0.1018 - val_cls_loss: 0.0661 - val_box_loss: 7.1374e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1863
# Epoch 25/50
# 296/296 [==============================] - 162s 549ms/step - det_loss: 0.2812 - cls_loss: 0.1825 - box_loss: 0.0020 - reg_l2_loss: 0.0846 - loss: 0.3658 - learning_rate: 0.0050 - gradient_norm: 2.9440 - val_det_loss: 0.1100 - val_cls_loss: 0.0908 - val_box_loss: 3.8320e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1946
# Epoch 26/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2796 - cls_loss: 0.1813 - box_loss: 0.0020 - reg_l2_loss: 0.0847 - loss: 0.3643 - learning_rate: 0.0047 - gradient_norm: 3.0202 - val_det_loss: 0.1330 - val_cls_loss: 0.0943 - val_box_loss: 7.7370e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.2177
# Epoch 27/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2635 - cls_loss: 0.1709 - box_loss: 0.0019 - reg_l2_loss: 0.0847 - loss: 0.3482 - learning_rate: 0.0044 - gradient_norm: 2.9493 - val_det_loss: 0.1243 - val_cls_loss: 0.0965 - val_box_loss: 5.5497e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.2090
# Epoch 28/50
# 296/296 [==============================] - 146s 495ms/step - det_loss: 0.2635 - cls_loss: 0.1712 - box_loss: 0.0018 - reg_l2_loss: 0.0847 - loss: 0.3482 - learning_rate: 0.0040 - gradient_norm: 2.9111 - val_det_loss: 0.1015 - val_cls_loss: 0.0809 - val_box_loss: 4.1262e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.1862
# Epoch 29/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2585 - cls_loss: 0.1670 - box_loss: 0.0018 - reg_l2_loss: 0.0847 - loss: 0.3432 - learning_rate: 0.0037 - gradient_norm: 3.0451 - val_det_loss: 0.1690 - val_cls_loss: 0.1264 - val_box_loss: 8.5168e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.2538
# Epoch 30/50
# 296/296 [==============================] - 162s 548ms/step - det_loss: 0.2562 - cls_loss: 0.1674 - box_loss: 0.0018 - reg_l2_loss: 0.0848 - loss: 0.3409 - learning_rate: 0.0034 - gradient_norm: 2.9766 - val_det_loss: 0.0953 - val_cls_loss: 0.0769 - val_box_loss: 3.6849e-04 - val_reg_l2_loss: 0.0848 - val_loss: 0.1801
# Epoch 31/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2523 - cls_loss: 0.1658 - box_loss: 0.0017 - reg_l2_loss: 0.0848 - loss: 0.3371 - learning_rate: 0.0031 - gradient_norm: 2.9859 - val_det_loss: 0.1267 - val_cls_loss: 0.1019 - val_box_loss: 4.9561e-04 - val_reg_l2_loss: 0.0848 - val_loss: 0.2114
# Epoch 32/50
# 296/296 [==============================] - 147s 495ms/step - det_loss: 0.2425 - cls_loss: 0.1573 - box_loss: 0.0017 - reg_l2_loss: 0.0848 - loss: 0.3272 - learning_rate: 0.0028 - gradient_norm: 2.9737 - val_det_loss: 0.0977 - val_cls_loss: 0.0809 - val_box_loss: 3.3645e-04 - val_reg_l2_loss: 0.0848 - val_loss: 0.1825
# Epoch 33/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2407 - cls_loss: 0.1550 - box_loss: 0.0017 - reg_l2_loss: 0.0848 - loss: 0.3254 - learning_rate: 0.0025 - gradient_norm: 2.9175 - val_det_loss: 0.0978 - val_cls_loss: 0.0772 - val_box_loss: 4.1115e-04 - val_reg_l2_loss: 0.0848 - val_loss: 0.1825
# Epoch 34/50
# 296/296 [==============================] - 146s 494ms/step - det_loss: 0.2394 - cls_loss: 0.1575 - box_loss: 0.0016 - reg_l2_loss: 0.0847 - loss: 0.3241 - learning_rate: 0.0023 - gradient_norm: 2.9948 - val_det_loss: 0.0938 - val_cls_loss: 0.0750 - val_box_loss: 3.7694e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.1786
# Epoch 35/50
# 296/296 [==============================] - 162s 549ms/step - det_loss: 0.2323 - cls_loss: 0.1516 - box_loss: 0.0016 - reg_l2_loss: 0.0847 - loss: 0.3170 - learning_rate: 0.0020 - gradient_norm: 2.9330 - val_det_loss: 0.0912 - val_cls_loss: 0.0740 - val_box_loss: 3.4426e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.1760
# Epoch 36/50
# 296/296 [==============================] - 146s 492ms/step - det_loss: 0.2234 - cls_loss: 0.1459 - box_loss: 0.0015 - reg_l2_loss: 0.0847 - loss: 0.3081 - learning_rate: 0.0018 - gradient_norm: 2.8438 - val_det_loss: 0.0956 - val_cls_loss: 0.0783 - val_box_loss: 3.4439e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.1803
# Epoch 37/50
# 296/296 [==============================] - 146s 495ms/step - det_loss: 0.2213 - cls_loss: 0.1456 - box_loss: 0.0015 - reg_l2_loss: 0.0847 - loss: 0.3061 - learning_rate: 0.0015 - gradient_norm: 2.8466 - val_det_loss: 0.0889 - val_cls_loss: 0.0738 - val_box_loss: 3.0080e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.1736
# Epoch 38/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2174 - cls_loss: 0.1419 - box_loss: 0.0015 - reg_l2_loss: 0.0847 - loss: 0.3020 - learning_rate: 0.0013 - gradient_norm: 2.7408 - val_det_loss: 0.0875 - val_cls_loss: 0.0728 - val_box_loss: 2.9265e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.1721
# Epoch 39/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2183 - cls_loss: 0.1443 - box_loss: 0.0015 - reg_l2_loss: 0.0847 - loss: 0.3030 - learning_rate: 0.0011 - gradient_norm: 2.8790 - val_det_loss: 0.0896 - val_cls_loss: 0.0746 - val_box_loss: 3.0010e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.1743
# Epoch 40/50
# 296/296 [==============================] - 162s 546ms/step - det_loss: 0.2165 - cls_loss: 0.1418 - box_loss: 0.0015 - reg_l2_loss: 0.0847 - loss: 0.3012 - learning_rate: 8.9985e-04 - gradient_norm: 2.7361 - val_det_loss: 0.0910 - val_cls_loss: 0.0742 - val_box_loss: 3.3554e-04 - val_reg_l2_loss: 0.0847 - val_loss: 0.1757
# Epoch 41/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2080 - cls_loss: 0.1382 - box_loss: 0.0014 - reg_l2_loss: 0.0846 - loss: 0.2927 - learning_rate: 7.2503e-04 - gradient_norm: 2.8233 - val_det_loss: 0.0914 - val_cls_loss: 0.0759 - val_box_loss: 3.1118e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1761
# Epoch 42/50
# 296/296 [==============================] - 147s 496ms/step - det_loss: 0.2031 - cls_loss: 0.1336 - box_loss: 0.0014 - reg_l2_loss: 0.0846 - loss: 0.2878 - learning_rate: 5.6777e-04 - gradient_norm: 2.7222 - val_det_loss: 0.0898 - val_cls_loss: 0.0738 - val_box_loss: 3.2028e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1744
# Epoch 43/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2033 - cls_loss: 0.1345 - box_loss: 0.0014 - reg_l2_loss: 0.0846 - loss: 0.2879 - learning_rate: 4.2873e-04 - gradient_norm: 2.7980 - val_det_loss: 0.0862 - val_cls_loss: 0.0706 - val_box_loss: 3.1076e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1708
# Epoch 44/50
# 296/296 [==============================] - 146s 492ms/step - det_loss: 0.2035 - cls_loss: 0.1354 - box_loss: 0.0014 - reg_l2_loss: 0.0846 - loss: 0.2882 - learning_rate: 3.0847e-04 - gradient_norm: 2.8321 - val_det_loss: 0.0870 - val_cls_loss: 0.0715 - val_box_loss: 3.1059e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1716
# Epoch 45/50
# 296/296 [==============================] - 163s 549ms/step - det_loss: 0.2032 - cls_loss: 0.1334 - box_loss: 0.0014 - reg_l2_loss: 0.0846 - loss: 0.2878 - learning_rate: 2.0749e-04 - gradient_norm: 2.7065 - val_det_loss: 0.0898 - val_cls_loss: 0.0739 - val_box_loss: 3.1767e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1744
# Epoch 46/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2034 - cls_loss: 0.1342 - box_loss: 0.0014 - reg_l2_loss: 0.0846 - loss: 0.2880 - learning_rate: 1.2620e-04 - gradient_norm: 2.8566 - val_det_loss: 0.0880 - val_cls_loss: 0.0725 - val_box_loss: 3.1057e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1726
# Epoch 47/50
# 296/296 [==============================] - 147s 495ms/step - det_loss: 0.2081 - cls_loss: 0.1372 - box_loss: 0.0014 - reg_l2_loss: 0.0846 - loss: 0.2927 - learning_rate: 6.4943e-05 - gradient_norm: 2.8381 - val_det_loss: 0.0883 - val_cls_loss: 0.0724 - val_box_loss: 3.1943e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1729
# Epoch 48/50
# 296/296 [==============================] - 146s 493ms/step - det_loss: 0.2023 - cls_loss: 0.1352 - box_loss: 0.0013 - reg_l2_loss: 0.0846 - loss: 0.2870 - learning_rate: 2.3963e-05 - gradient_norm: 2.8105 - val_det_loss: 0.0887 - val_cls_loss: 0.0726 - val_box_loss: 3.2220e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1733
# Epoch 49/50
# 296/296 [==============================] - 147s 495ms/step - det_loss: 0.2010 - cls_loss: 0.1327 - box_loss: 0.0014 - reg_l2_loss: 0.0846 - loss: 0.2856 - learning_rate: 3.4306e-06 - gradient_norm: 2.6889 - val_det_loss: 0.0880 - val_cls_loss: 0.0721 - val_box_loss: 3.1818e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1727
# Epoch 50/50
# 296/296 [==============================] - 163s 549ms/step - det_loss: 0.2012 - cls_loss: 0.1325 - box_loss: 0.0014 - reg_l2_loss: 0.0846 - loss: 0.2858 - learning_rate: 3.4304e-06 - gradient_norm: 2.7232 - val_det_loss: 0.0884 - val_cls_loss: 0.0726 - val_box_loss: 3.1690e-04 - val_reg_l2_loss: 0.0846 - val_loss: 0.1730

# %% [markdown]
# Create another folder for test data
# train, val, test in 80 20 20 %

# %%
model.evaluate(val_ds)
# Out:
# 10/10 [==============================] - 26s 1s/step
# {'AP': 0.77590483,
#  'AP50': 0.9306037,
#  'AP75': 0.82599777,
#  'AP_/pistol': 0.77590483,
#  'APl': 0.85372925,
#  'APm': 0.2465957,
#  'APs': 0.107672036,
#  'ARl': 0.9,
#  'ARm': 0.48181817,
#  'ARmax1': 0.7591615,
#  'ARmax10': 0.821118,
#  'ARmax100': 0.835559,
#  'ARs': 0.22857143}

# %% [markdown]
# Export

# %%
model.export(export_dir='.')

# %%
model.export(export_dir='.', export_format=[ExportFormat.SAVED_MODEL, ExportFormat.LABEL])

# %% [markdown]
# For downloading saved model
#   Create a zip & download

# %%
# !zip -r /content/saved_model.zip /content/saved_model
# Out:
#   adding: content/saved_model/ (stored 0%)
#   adding: content/saved_model/assets/ (stored 0%)
#   adding: content/saved_model/saved_model.pb (deflated 91%)
#   adding: content/saved_model/variables/ (stored 0%)
#   adding: content/saved_model/variables/variables.index (deflated 85%)
#   adding: content/saved_model/variables/variables.data-00000-of-00001 (deflated 8%)

# %% [markdown]
# -----------------------------------------------------------
#
# # ***Doesn't Work***

# %% [markdown]
# Test TFLite model & compare against previous evaluation

# %%
# !mv "/content/val/armas (2403).jpg.rf.f8404accb1bd5bd688d946ee52a45c2b.jpg" "/content/test"

# %%
test_ds = object_detector.DataLoader.from_pascal_voc(images_dir=val_image_dir,
                                                      annotations_dir= val_image_dir,
                                                      label_map=label_map,
                                                      cache_dir='/content/cache/train'
                                                     )

# %%
model.evaluate_tflite('model.tflite', "/content/test" )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-372649988ee6> in <module>()
# ----> 1 model.evaluate_tflite('model.tflite', "/content/test" )
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_examples/lite/model_maker/core/task/object_detector.py in evaluate_tflite(self, tflite_filepath, data)
#     152       data: object_detector_dataloader.DataLoader) -> Dict[str, float]:
#     153     """Evaluate the TFLite model."""
# --> 154     ds = data.gen_dataset(self.model_spec, batch_size=1, is_training=False)
#     155     return self.model_spec.evaluate_tflite(tflite_filepath, ds, len(data),
#     156                                            data.annotations_json_file)
#
# AttributeError: 'str' object has no attribute 'gen_dataset'

# %% [markdown]
# ----------------------------------------------

# %% [markdown]
# ## (Optional) Test the TFLite model on your image
#
# You can test the trained TFLite model using images from the internet.
# * Replace the `INPUT_IMAGE_URL` below with your desired input image.
# * Adjust the `DETECTION_THRESHOLD` to change the sensitivity of the model. A lower threshold means the model will pickup more objects but there will also be more false detection. Meanwhile, a higher threshold means the model will only pickup objects that it has confidently detected.
#
# Although it requires some of boilerplate code to run the model in Python at this moment, integrating the model into a mobile app only requires a few lines of code.

# %% [markdown]
# **Run THIS**
#
# OTHERWISE the next code block will give error

# %%
# !pip uninstall opencv-python-headless
# !pip install opencv-python-headless==4.1.2.30
# Out:
# Found existing installation: opencv-python-headless 4.5.5.62
# Uninstalling opencv-python-headless-4.5.5.62:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/cv2/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless-4.5.5.62.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavcodec-64ac49e1.so.58.91.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavformat-4b79e479.so.58.45.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libavutil-805734e8.so.56.51.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libbz2-a273e504.so.1.0.6
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libcrypto-018b8c17.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libgfortran-91cc3cb1.so.3.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libopenblas-r0-f650aae0.3.3.so
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libpng15-ce838cd1.so.15.13.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libssl-6082116c.so.1.1
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libswresample-83ce3247.so.3.7.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libswscale-7e960168.so.5.7.100
#     /usr/local/lib/python3.7/dist-packages/opencv_python_headless.libs/libvpx-392cd848.so.6.4.0
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtCore-bbdab771.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtGui-903938cd.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libQtTest-1183da5d.so.4.8.7
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libavcodec-3cdd3bd4.so.58.62.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libavformat-69a63b50.so.58.35.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libavutil-8e8979a8.so.56.36.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libbz2-7225278b.so.1.0.3
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libcrypto-a25ff511.so.1.1
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libssl-fdf0b66c.so.1.1
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libswresample-c6b3bbb9.so.3.6.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libswscale-2d19f7d1.so.5.6.100
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libvpx-c887ea55.so.6.1.0
#     /usr/local/lib/python3.7/dist-packages/cv2/.libs/libz-a147dcb0.so.1.2.3
#     /usr/local/lib/python3.7/dist-packages/cv2/cv2.cpython-37m-x86_64-linux-gnu.so
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-headless-4.5.5.62
# Collecting opencv-python-headless==4.1.2.30
#   Downloading opencv_python_headless-4.1.2.30-cp37-cp37m-manylinux1_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 3.4 MB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python-headless==4.1.2.30) (1.21.5)
# Installing collected packages: opencv-python-headless
# Successfully installed opencv-python-headless-4.1.2.30

# %%
#@title Load the trained TFLite model and define some visualization functions

import cv2

from PIL import Image

model_path = 'model.tflite'

# Load the labels into a list
classes = ['???'] * model.model_spec.config.num_classes
label_map = model.model_spec.config.label_map
for label_id, label_name in label_map.as_dict().items():
  classes[label_id-1] = label_name

# Define a list of colors for visualization
COLORS = np.random.randint(0, 255, size=(len(classes), 3), dtype=np.uint8)

def preprocess_image(image_path, input_size):
  """Preprocess the input image to feed to the TFLite model"""
  img = tf.io.read_file(image_path)
  img = tf.io.decode_image(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.uint8)
  original_image = img
  resized_img = tf.image.resize(img, input_size)
  resized_img = resized_img[tf.newaxis, :]
  resized_img = tf.cast(resized_img, dtype=tf.uint8)
  return resized_img, original_image


def detect_objects(interpreter, image, threshold):
  """Returns a list of detection results, each a dictionary of object info."""

  signature_fn = interpreter.get_signature_runner()

  # Feed the input image to the model
  output = signature_fn(images=image)

  # Get all outputs from the model
  count = int(np.squeeze(output['output_0']))
  scores = np.squeeze(output['output_1'])
  classes = np.squeeze(output['output_2'])
  boxes = np.squeeze(output['output_3'])

  results = []
  for i in range(count):
    if scores[i] >= threshold:
      result = {
        'bounding_box': boxes[i],
        'class_id': classes[i],
        'score': scores[i]
      }
      results.append(result)
  return results


def run_odt_and_draw_results(image_path, interpreter, threshold=0.5):
  """Run object detection on the input image and draw the detection results"""
  # Load the input shape required by the model
  _, input_height, input_width, _ = interpreter.get_input_details()[0]['shape']

  # Load the input image and preprocess it
  preprocessed_image, original_image = preprocess_image(
      image_path,
      (input_height, input_width)
    )

  # Run object detection on the input image
  results = detect_objects(interpreter, preprocessed_image, threshold=threshold)

  # Plot the detection results on the input image
  original_image_np = original_image.numpy().astype(np.uint8)
  for obj in results:
    # Convert the object bounding box from relative coordinates to absolute
    # coordinates based on the original image resolution
    ymin, xmin, ymax, xmax = obj['bounding_box']
    xmin = int(xmin * original_image_np.shape[1])
    xmax = int(xmax * original_image_np.shape[1])
    ymin = int(ymin * original_image_np.shape[0])
    ymax = int(ymax * original_image_np.shape[0])

    # Find the class index of the current object
    class_id = int(obj['class_id'])

    # Draw the bounding box and label on the image
    color = [int(c) for c in COLORS[class_id]]
    cv2.rectangle(original_image_np, (xmin, ymin), (xmax, ymax), color, 2)
    # Make adjustments to make the label visible for all objects
    y = ymin - 15 if ymin - 15 > 15 else ymin + 15
    label = "{}: {:.0f}%".format(classes[class_id], obj['score'] * 100)
    cv2.putText(original_image_np, label, (xmin, y),
        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

  # Return the final image
  original_uint8 = original_image_np.astype(np.uint8)
  return original_uint8

# %%
#@title Run object detection and show the detection results

INPUT_IMAGE_URL = "http://www.imfdb.org/images/thumb/0/07/AoT-Gasser-1.jpg/600px-AoT-Gasser-1.jpg" #@param {type:"string"}
DETECTION_THRESHOLD = 0.3 #@param {type:"number"}

TEMP_FILE = '/tmp/image.png'

# !wget -q -O $TEMP_FILE $INPUT_IMAGE_URL
im = Image.open(TEMP_FILE)
im.thumbnail((512, 512), Image.ANTIALIAS)
im.save(TEMP_FILE, 'PNG')

# Load the TFLite model
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Run inference and draw detection result on the local copy of the original file
detection_result_image = run_odt_and_draw_results(
    TEMP_FILE,
    interpreter,
    threshold=DETECTION_THRESHOLD
)

# Show the detection result
Image.fromarray(detection_result_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x273 at 0x7F3ABF1F8B50>

# %% [markdown]
# USE this website to test for images
# http://www.imfdb.org/wiki/Assassination_of_Trotsky,_The
# .jpg url of images in there
